# %%
import pandas as pd
from src import DatasetManager, MinMaxScaling
from GDSC import GDSCPreprocessingPipeline
import os
import numpy as np
from GraphCreator import GraphCreator
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from src import DrugFeaturizer

# %%
manager = DatasetManager(GDSCPreprocessingPipeline(dataset = "GDSC1",
                                                   target = "LN_IC50"),
                        MinMaxScaling(),
                        partition_column = "CELL_ID",
                        drug_featurizer = GraphCreator())

# %%
train, val, test = manager.get_partition(1)

# %%
val
# Out:
#         CELL_ID            DRUG_ID         Y
# 9270     687819  (5Z)-7-Oxozeaenol  0.062643
# 9271     687819     5-Fluorouracil  0.398350
# 9272     687819            A-83-01  0.212381
# 9273     687819           ACY-1215  0.114535
# 9274     687819           AGI-6780  0.084903
# ...         ...                ...       ...
# 225007  1330994            Wnt-C59  0.126663
# 225008  1330994             XAV939  0.186176
# 225009  1330994           YK-4-279 -0.051463
# 225010  1330994           ZM447439 -0.111509
# 225011  1330994       kb NB 142-70 -0.021276
#
# [9449 rows x 3 columns]

# %%
manager.get_cell_lines()
# Out:
#            TSPAN6      TNMD       DPM1     SCYL3  C1orf112       FGR  \
# index
# 683667   7.780713  2.753253   9.960137  4.351073  3.716740  3.222277
# 684052   7.301344  2.890533   9.922489  4.125088  3.678987  3.096576
# 684057   8.233101  2.824687  10.015884  4.749715  3.839433  3.142754
# 684059   8.333466  3.966757   9.793991  3.976923  3.505669  3.079943
# 684062   8.391341  2.968360  10.260680  4.295875  4.129471  3.318760
# ...           ...       ...        ...       ...       ...       ...
# 1659928  7.245503  2.898369   9.737324  4.295495  3.429522  3.264985
# 1660034  8.579664  2.778771   9.768011  5.713156  4.455503  3.388605
# 1660035  8.077116  2.781325  10.038055  5.205411  3.758069  3.111444
# 1660036  7.797699  2.640900   9.463400  4.039697  3.854522  3.212820
# 1674021  7.606903  3.157319  10.153141  3.768090  3.502940  3.219493
#
#               CFH     FUCA2      GCLC      NFYA  ...  LINC00526      PPY2  \
# index                                            ...
# ...

# %%
drug_dict = manager.get_drugs()

# %%
drug_dict
# Out:
# {'5-Fluorouracil': Data(x=[9, 79], edge_index=[2, 18], edge_attr=[18, 10]),
#  'A-83-01': Data(x=[31, 79], edge_index=[2, 70], edge_attr=[70, 10]),
#  'ACY-1215': Data(x=[32, 79], edge_index=[2, 68], edge_attr=[68, 10]),
#  'AGI-6780': Data(x=[32, 79], edge_index=[2, 70], edge_attr=[70, 10]),
#  'AICA Ribonucleotide': Data(x=[22, 79], edge_index=[2, 46], edge_attr=[46, 10]),
#  'AKT inhibitor VIII': Data(x=[42, 79], edge_index=[2, 98], edge_attr=[98, 10]),
#  'AR-42': Data(x=[23, 79], edge_index=[2, 48], edge_attr=[48, 10]),
#  'ARRY-520': Data(x=[29, 79], edge_index=[2, 62], edge_attr=[62, 10]),
#  'AS601245': Data(x=[27, 79], edge_index=[2, 60], edge_attr=[60, 10]),
#  'AS605240': Data(x=[18, 79], edge_index=[2, 40], edge_attr=[40, 10]),
#  'AST-1306': Data(x=[32, 79], edge_index=[2, 70], edge_attr=[70, 10]),
#  'AT-7519': Data(x=[25, 79], edge_index=[2, 54], edge_attr=[54, 10]),
#  'AT7867': Data(x=[24, 79], edge_index=[2, 54], edge_attr=[54, 10]),
# ...
